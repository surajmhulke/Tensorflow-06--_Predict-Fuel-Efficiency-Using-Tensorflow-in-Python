# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import tensorflow as tf
from tensorflow import keras
from keras import layers

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
print(df.shape)
df = df[df['horsepower'] != '?']
print(df.shape)
# Out:
# (398, 9)
# (392, 9)

# %%
df['horsepower'] = df['horsepower'].astype(int)
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.nunique()
# Out:
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# model year       13
# origin            3
# car name        301
# dtype: int64

# %%
plt.subplots(figsize=(15, 5))
for i, col in enumerate(['cylinders', 'origin']):
	plt.subplot(1, 2, i+1)
	x = df.groupby(col).mean()['mpg']
	x.plot.bar()
	plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
sb.heatmap(df.corr() > 0.9,
		annot=True,
		cbar=False)
plt.show()

# %%
df.drop('displacement',
		axis=1,
		inplace=True)

# %%
from sklearn.model_selection import train_test_split
features = df.drop(['mpg', 'car name'], axis=1)
target = df['mpg'].values

X_train, X_val, \
	Y_train, Y_val = train_test_split(features, target,
									test_size=0.2,
									random_state=22)
X_train.shape, X_val.shape
# Out:
# ((313, 6), (79, 6))

# %%
AUTO = tf.data.experimental.AUTOTUNE

train_ds = (
	tf.data.Dataset
	.from_tensor_slices((X_train, Y_train))
	.batch(32)
	.prefetch(AUTO)
)

val_ds = (
	tf.data.Dataset
	.from_tensor_slices((X_val, Y_val))
	.batch(32)
	.prefetch(AUTO)
)

# %%
model = keras.Sequential([
	layers.Dense(256, activation='relu', input_shape=[6]),
	layers.BatchNormalization(),
	layers.Dense(256, activation='relu'),
	layers.Dropout(0.3),
	layers.BatchNormalization(),
	layers.Dense(1, activation='relu')
])

# %%
model.compile(
	loss='mae',
	optimizer='adam',
	metrics=['mape']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1792
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 69889 (273.00 KB)
# Trainable params: 68865 (269.00 KB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
history = model.fit(train_ds,
					epochs=50,
					validation_data=val_ds)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 16ms/step - loss: 21.3930 - mape: 85.8880 - val_loss: 24.7917 - val_mape: 152.0175
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 19.6603 - mape: 75.3603 - val_loss: 22.5774 - val_mape: 137.4554
# Epoch 3/50
# 10/10 [==============================] - 0s 3ms/step - loss: 19.1885 - mape: 73.2051 - val_loss: 14.7403 - val_mape: 81.8425
# Epoch 4/50
# 10/10 [==============================] - 0s 4ms/step - loss: 18.5571 - mape: 69.9519 - val_loss: 12.1721 - val_mape: 61.5316
# Epoch 5/50
# 10/10 [==============================] - 0s 3ms/step - loss: 17.9341 - mape: 66.8491 - val_loss: 10.4615 - val_mape: 43.3162
# Epoch 6/50
# 10/10 [==============================] - 0s 3ms/step - loss: 17.4150 - mape: 64.5791 - val_loss: 10.2512 - val_mape: 40.3188
# Epoch 7/50
# 10/10 [==============================] - 0s 3ms/step - loss: 16.9497 - mape: 62.4375 - val_loss: 9.9404 - val_mape: 37.4450
# Epoch 8/50
# 10/10 [==============================] - 0s 3ms/step - loss: 16.3605 - mape: 59.8049 - val_loss: 10.1682 - val_mape: 37.8924
# Epoch 9/50
# 10/10 [==============================] - 0s 4ms/step - loss: 15.6625 - mape: 56.6876 - val_loss: 9.0029 - val_mape: 34.3409
# Epoch 10/50
# 10/10 [==============================] - 0s 4ms/step - loss: 15.4228 - mape: 56.2952 - val_loss: 8.0267 - val_mape: 30.8094
# Epoch 11/50
# 10/10 [==============================] - 0s 3ms/step - loss: 14.7401 - mape: 52.9114 - val_loss: 7.3693 - val_mape: 28.4635
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 14.0628 - mape: 50.1103 - val_loss: 6.8233 - val_mape: 26.8449
# Epoch 13/50
# 10/10 [==============================] - 0s 6ms/step - loss: 13.5715 - mape: 48.5248 - val_loss: 5.6628 - val_mape: 22.0575
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 12.8673 - mape: 45.1738 - val_loss: 5.5242 - val_mape: 23.7221
# Epoch 15/50
# 10/10 [==============================] - 0s 6ms/step - loss: 12.4747 - mape: 44.3483 - val_loss: 4.0348 - val_mape: 15.4635
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 11.8209 - mape: 41.5041 - val_loss: 3.6506 - val_mape: 14.2998
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 11.4732 - mape: 40.7197 - val_loss: 3.8082 - val_mape: 16.3278
# Epoch 18/50
# 10/10 [==============================] - 0s 5ms/step - loss: 11.3021 - mape: 40.1263 - val_loss: 4.0536 - val_mape: 18.5007
# Epoch 19/50
# 10/10 [==============================] - 0s 5ms/step - loss: 11.0246 - mape: 39.3251 - val_loss: 3.6125 - val_mape: 15.7890
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 10.7325 - mape: 38.0912 - val_loss: 4.2583 - val_mape: 19.7389
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 10.5785 - mape: 38.0451 - val_loss: 4.3277 - val_mape: 20.2323
# Epoch 22/50
# 10/10 [==============================] - 0s 5ms/step - loss: 10.1575 - mape: 36.1645 - val_loss: 5.0685 - val_mape: 24.4347
# Epoch 23/50
# 10/10 [==============================] - 0s 5ms/step - loss: 10.0571 - mape: 36.1526 - val_loss: 6.7079 - val_mape: 33.4571
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.8574 - mape: 35.4619 - val_loss: 7.3652 - val_mape: 34.7923
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.4007 - mape: 34.0875 - val_loss: 8.9138 - val_mape: 45.1778
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.0616 - mape: 33.0060 - val_loss: 10.2211 - val_mape: 55.1641
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 8.6498 - mape: 30.9073 - val_loss: 11.3799 - val_mape: 60.6345
# Epoch 28/50
# 10/10 [==============================] - 0s 5ms/step - loss: 8.1784 - mape: 29.9738 - val_loss: 8.6840 - val_mape: 44.9240
# Epoch 29/50
# 10/10 [==============================] - 0s 5ms/step - loss: 7.6662 - mape: 28.8879 - val_loss: 11.5768 - val_mape: 61.0693
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 6.6782 - mape: 24.9201 - val_loss: 10.5406 - val_mape: 56.1401
# Epoch 31/50
# 10/10 [==============================] - 0s 6ms/step - loss: 5.2589 - mape: 20.6288 - val_loss: 9.2979 - val_mape: 50.7077
# Epoch 32/50
# 10/10 [==============================] - 0s 6ms/step - loss: 3.9472 - mape: 16.2799 - val_loss: 8.8964 - val_mape: 49.1186
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 3.2515 - mape: 13.7196 - val_loss: 8.7195 - val_mape: 48.5320
# Epoch 34/50
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0074 - mape: 13.3793 - val_loss: 9.8320 - val_mape: 55.4994
# Epoch 35/50
# 10/10 [==============================] - 0s 3ms/step - loss: 3.2504 - mape: 14.5512 - val_loss: 9.6452 - val_mape: 53.1910
# Epoch 36/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8361 - mape: 12.3347 - val_loss: 9.3004 - val_mape: 51.1191
# Epoch 37/50
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0389 - mape: 13.2349 - val_loss: 7.0845 - val_mape: 38.1886
# Epoch 38/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8663 - mape: 12.5271 - val_loss: 6.6481 - val_mape: 35.7005
# Epoch 39/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9009 - mape: 12.8805 - val_loss: 5.1746 - val_mape: 26.3242
# Epoch 40/50
# 10/10 [==============================] - 0s 3ms/step - loss: 3.0380 - mape: 13.2600 - val_loss: 4.4044 - val_mape: 21.6328
# Epoch 41/50
# 10/10 [==============================] - 0s 5ms/step - loss: 2.9501 - mape: 12.8342 - val_loss: 4.7904 - val_mape: 23.6928
# Epoch 42/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9546 - mape: 13.3001 - val_loss: 4.7202 - val_mape: 25.3838
# Epoch 43/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9993 - mape: 13.3358 - val_loss: 4.4733 - val_mape: 22.6698
# Epoch 44/50
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9489 - mape: 13.1384 - val_loss: 5.4778 - val_mape: 27.5148
# Epoch 45/50
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8515 - mape: 12.5092 - val_loss: 4.7455 - val_mape: 23.4309
# Epoch 46/50
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9256 - mape: 12.8099 - val_loss: 3.6736 - val_mape: 18.3408
# Epoch 47/50
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8153 - mape: 12.7401 - val_loss: 6.3670 - val_mape: 32.1582
# Epoch 48/50
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8502 - mape: 12.4263 - val_loss: 6.7011 - val_mape: 33.8677
# Epoch 49/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.8327 - mape: 12.3409 - val_loss: 9.5114 - val_mape: 50.1543
# Epoch 50/50
# 10/10 [==============================] - 0s 3ms/step - loss: 2.9287 - mape: 13.3381 - val_loss: 8.0112 - val_mape: 40.0203

# %%
history_df = pd.DataFrame(history.history)
history_df.head()
# Out:
#         loss       mape   val_loss    val_mape
# 0  21.393021  85.887970  24.791750  152.017502
# 1  19.660273  75.360260  22.577354  137.455429
# 2  19.188452  73.205116  14.740261   81.842491
# 3  18.557079  69.951920  12.172099   61.531639
# 4  17.934147  66.849113  10.461517   43.316204

# %%
history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['mape', 'val_mape']].plot()
plt.show()
